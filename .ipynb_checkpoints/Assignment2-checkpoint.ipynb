# %% [markdown]
# ### Assignment2

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
from torchvision import models
import matplotlib.pyplot as plt
import time

# %%
#load cifar10
transform_train = transforms.Compose([
    transforms.ToTensor(),
    transforms.RandomCrop(32, padding=4),          
    transforms.RandomHorizontalFlip(),               
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010))
    
])
transform = transforms.Compose([
    transforms.ToTensor(),           
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010))
    
])

#train validation set
trainval = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform)
trainval_transform = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform_train)

#split trainval into trainset and valset 
trainset,valset = torch.utils.data.random_split(trainval, [0.9, 0.1])
trainset_transform,valset_transform = torch.utils.data.random_split(trainval_transform, [0.9, 0.1])

#trainloader 
trainloader = torch.utils.data.DataLoader(trainset, batch_size=64, shuffle=True, num_workers=0)
trainloader_transform = torch.utils.data.DataLoader(trainset_transform, batch_size=64, shuffle=True, num_workers=0)
trainloader2 = torch.utils.data.DataLoader(trainset_transform, batch_size=128, shuffle=True, num_workers=0)
#valloader
valloader = torch.utils.data.DataLoader(valset, batch_size=4, shuffle=True, num_workers=0)
valloader_transform = torch.utils.data.DataLoader(valset_transform, batch_size=4, shuffle=True, num_workers=0)

#test set
testset = trainval = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform)
#testloader
testloader = torch.utils.data.DataLoader(testset, batch_size=4, shuffle=False, num_workers=2)
#classes
classes = ('plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck')
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified

# %%
#cuda device
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda:0

# %%
def train_plot(num_epochs,model,criterion,optimizer,trainloader,valloader):
    start_time = time.time()
    train_losses = []
    val_losses = []
    train_accuracies = []
    val_accuracies = []
    for epoch in range(num_epochs):
        epoch_start = time.time()
        #training
        model.train()  
        running_loss = 0.0
        correct_train = 0
        total_train = 0
        
        for inputs, labels in trainloader:
            inputs, labels = inputs.to(device), labels.to(device)
            
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            
            running_loss += loss.item()
            
            # calculate trainset's accuracy
            _, predicted = torch.max(outputs, 1)
            total_train += labels.size(0)
            correct_train += (predicted == labels).sum().item()
        
        train_loss = running_loss / len(trainloader)
        train_accuracy = 100 * correct_train / total_train
        train_losses.append(train_loss)
        train_accuracies.append(train_accuracy)
        
        #validating
        model.eval() 
        val_loss = 0.0
        correct_val = 0
        total_val = 0
        
        with torch.no_grad():  
            for inputs, labels in valloader:
                inputs, labels = inputs.to(device), labels.to(device)
                outputs = model(inputs)
                loss = criterion(outputs, labels)
                val_loss += loss.item()
                
                #calculate valset's accuracy
                _, predicted = torch.max(outputs, 1)
                total_val += labels.size(0)
                correct_val += (predicted == labels).sum().item()
        
        val_loss = val_loss / len(valloader)
        val_accuracy = 100 * correct_val / total_val
        val_losses.append(val_loss)
        val_accuracies.append(val_accuracy)
        epoch_time = time.time()-epoch_start
        # print
        print(f"Epoch [{epoch+1}/{num_epochs}], Time:{epoch_time:.2f}s, "
              f"Train Loss: {train_loss:.4f}, Train Accuracy: {train_accuracy:.2f}%, "
              f"Validation Loss: {val_loss:.4f}, Validation Accuracy: {val_accuracy:.2f}%")
    total_time = time.time()-start_time
    print(f"Total Time:{total_time:.2f}s")
    # plot loss curve
    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(range(1, num_epochs + 1), train_losses, label='Train Loss')
    plt.plot(range(1, num_epochs + 1), val_losses, label='Validation Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.title('Training and Validation Loss')
    plt.legend()
    
    # plot accuracy curve
    plt.subplot(1, 2, 2)
    plt.plot(range(1, num_epochs + 1), train_accuracies, label='Train Accuracy')
    plt.plot(range(1, num_epochs + 1), val_accuracies, label='Validation Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy (%)')
    plt.title('Training and Validation Accuracy')
    plt.legend()
    
    plt.show()

# %%
def test_accuracy(model):
    model.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for images, labels in testloader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
    
    print(f"Accuracy: {100 * correct / total:.2f}%")

# %%
#cnn model
model_vgg16 = models.vgg16(weights=None)  
model_vgg16.classifier[6] = nn.Linear(4096, 10) 
model_vgg16 = model_vgg16.to(device)

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model_vgg16.parameters(), lr=0.01, momentum=0.9, weight_decay=5e-4)

# %%
train_plot(20,model_vgg16,criterion,optimizer,trainloader,valloader)
# Out:
# Epoch [1/20], Time:52.86s, Train Loss: 1.8459, Train Accuracy: 28.08%, Validation Loss: 1.7113, Validation Accuracy: 38.82%
# Epoch [2/20], Time:51.48s, Train Loss: 1.3401, Train Accuracy: 50.62%, Validation Loss: 1.1713, Validation Accuracy: 58.14%
# Epoch [3/20], Time:51.55s, Train Loss: 1.0339, Train Accuracy: 63.30%, Validation Loss: 0.9174, Validation Accuracy: 68.56%
# Epoch [4/20], Time:51.55s, Train Loss: 0.8432, Train Accuracy: 70.88%, Validation Loss: 0.8038, Validation Accuracy: 72.98%
# Epoch [5/20], Time:51.53s, Train Loss: 0.7010, Train Accuracy: 76.38%, Validation Loss: 0.7415, Validation Accuracy: 74.72%
# Epoch [6/20], Time:51.55s, Train Loss: 0.5933, Train Accuracy: 79.88%, Validation Loss: 0.6941, Validation Accuracy: 76.86%
# Epoch [7/20], Time:51.51s, Train Loss: 0.5027, Train Accuracy: 83.04%, Validation Loss: 0.6359, Validation Accuracy: 78.86%
# ...

# %%
model_vgg16.eval()
correct = 0
total = 0
with torch.no_grad():
    for images, labels in testloader:
        images, labels = images.to(device), labels.to(device)
        outputs = model_vgg16(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

print(f"Accuracy: {100 * correct / total:.2f}%")
# Out:
# Accuracy: 81.31%

# %%
model_vgg16_mod1 = models.vgg16(weights=None) 
model_vgg16_mod1.classifier[6] = nn.Linear(4096, 10) 
model_vgg16_mod1 = model_vgg16_mod1.to(device)  
criterion_mod1 = nn.CrossEntropyLoss()
optimizer_mod1 = optim.SGD(model_vgg16_mod1.parameters(), lr=0.02, momentum=0.9, weight_decay=0.0015)

# %%
train_plot(20,model_vgg16_mod1,criterion_mod1,optimizer_mod1,trainloader,valloader)
# Out:
# Epoch [1/20], Time:51.38s, Train Loss: 1.9582, Train Accuracy: 22.63%, Validation Loss: 1.7775, Validation Accuracy: 28.98%
# Epoch [2/20], Time:51.45s, Train Loss: 1.5740, Train Accuracy: 39.56%, Validation Loss: 1.3380, Validation Accuracy: 50.60%
# Epoch [3/20], Time:51.39s, Train Loss: 1.2569, Train Accuracy: 55.00%, Validation Loss: 1.1577, Validation Accuracy: 60.22%
# Epoch [4/20], Time:51.41s, Train Loss: 1.0506, Train Accuracy: 63.86%, Validation Loss: 0.9661, Validation Accuracy: 66.56%
# Epoch [5/20], Time:51.36s, Train Loss: 0.9155, Train Accuracy: 69.12%, Validation Loss: 0.9526, Validation Accuracy: 69.62%
# Epoch [6/20], Time:51.37s, Train Loss: 0.8252, Train Accuracy: 72.76%, Validation Loss: 0.9349, Validation Accuracy: 69.16%
# Epoch [7/20], Time:51.34s, Train Loss: 0.7669, Train Accuracy: 74.98%, Validation Loss: 0.8749, Validation Accuracy: 72.46%
# ...

# %%
model_vgg16_mod1.eval()
correct = 0
total = 0
with torch.no_grad():
    for images, labels in testloader:
        images, labels = images.to(device), labels.to(device)
        outputs = model_vgg16_mod1(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

print(f"Accuracy: {100 * correct / total:.2f}%")
# Out:
# Accuracy: 79.28%

# %%
model_vgg16_mod2 = models.vgg16(weights=None) 
model_vgg16_mod2.classifier[6] = nn.Linear(4096, 10) 
model_vgg16_mod2 = model_vgg16_mod2.to(device)  
criterion_mod2 = nn.CrossEntropyLoss()
optimizer_mod2 = optim.SGD(model_vgg16_mod2.parameters(), lr=0.001, momentum=0.9, weight_decay=0.0015)

# %%
train_plot(20,model_vgg16_mod2,criterion_mod2,optimizer_mod2,trainloader2,valloader)
# Out:
# Epoch [1/20], Time:75.47s, Train Loss: 2.0032, Train Accuracy: 23.20%, Validation Loss: 1.7445, Validation Accuracy: 32.58%
# Epoch [2/20], Time:76.24s, Train Loss: 1.5312, Train Accuracy: 42.78%, Validation Loss: 1.3177, Validation Accuracy: 52.04%
# Epoch [3/20], Time:77.07s, Train Loss: 1.2554, Train Accuracy: 54.06%, Validation Loss: 1.1431, Validation Accuracy: 58.20%
# Epoch [4/20], Time:77.22s, Train Loss: 1.0537, Train Accuracy: 61.70%, Validation Loss: 0.9849, Validation Accuracy: 64.68%
# Epoch [5/20], Time:76.84s, Train Loss: 0.9070, Train Accuracy: 67.45%, Validation Loss: 0.8598, Validation Accuracy: 69.56%
# Epoch [6/20], Time:76.83s, Train Loss: 0.7806, Train Accuracy: 72.48%, Validation Loss: 0.7648, Validation Accuracy: 72.84%
# Epoch [7/20], Time:76.77s, Train Loss: 0.6750, Train Accuracy: 76.08%, Validation Loss: 0.7406, Validation Accuracy: 74.34%
# ...

# %%
model_vgg16_mod2.eval()
correct = 0
total = 0
with torch.no_grad():
    for images, labels in testloader:
        images, labels = images.to(device), labels.to(device)
        outputs = model_vgg16_mod2(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

print(f"Accuracy: {100 * correct / total:.2f}%")
# Out:
# Accuracy: 77.24%

# %%
model_vgg16_mod3 = models.vgg16(weights=None) 
model_vgg16_mod3.classifier[6] = nn.Linear(4096, 10) 
model_vgg16_mod3 = model_vgg16_mod3.to(device)  
criterion_mod3 = nn.CrossEntropyLoss()
optimizer_mod3 = optim.SGD(model_vgg16_mod3.parameters(), lr=0.01, momentum=0.9, weight_decay=0.0025)

# %%
train_plot(20,model_vgg16_mod3,criterion_mod3,optimizer_mod3,trainloader,valloader)
# Out:
# Epoch [1/20], Time:55.82s, Train Loss: 1.9102, Train Accuracy: 25.36%, Validation Loss: 1.8578, Validation Accuracy: 31.56%
# Epoch [2/20], Time:52.24s, Train Loss: 1.4163, Train Accuracy: 46.96%, Validation Loss: 1.2937, Validation Accuracy: 53.24%
# Epoch [3/20], Time:55.69s, Train Loss: 1.1182, Train Accuracy: 59.94%, Validation Loss: 1.1047, Validation Accuracy: 62.04%
# Epoch [4/20], Time:51.64s, Train Loss: 0.9488, Train Accuracy: 66.58%, Validation Loss: 0.8573, Validation Accuracy: 70.00%
# Epoch [5/20], Time:51.77s, Train Loss: 0.8211, Train Accuracy: 71.86%, Validation Loss: 0.8293, Validation Accuracy: 71.06%
# Epoch [6/20], Time:51.65s, Train Loss: 0.7305, Train Accuracy: 75.36%, Validation Loss: 0.7613, Validation Accuracy: 74.22%
# Epoch [7/20], Time:51.64s, Train Loss: 0.6636, Train Accuracy: 77.87%, Validation Loss: 0.7012, Validation Accuracy: 76.10%
# ...

# %%
model_vgg16_mod3.eval()
correct = 0
total = 0
with torch.no_grad():
    for images, labels in testloader:
        images, labels = images.to(device), labels.to(device)
        outputs = model_vgg16_mod3(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

print(f"Accuracy: {100 * correct / total:.2f}%")
# Out:
# Accuracy: 78.53%

# %%
model_vgg16_mod4= models.vgg16(weights=None) 
model_vgg16_mod4.classifier[6] = nn.Linear(4096, 10) 
model_vgg16_mod4 = model_vgg16_mod4.to(device)  
criterion_mod4 = nn.CrossEntropyLoss()
optimizer_mod4 = optim.SGD(model_vgg16_mod4.parameters(), lr=0.01, momentum=0.9, weight_decay=0.0025)

# %%
train_plot(20,model_vgg16_mod4,criterion,optimizer_mod4,trainloader_transform,valloader_transform)
# Out:
# Epoch [1/20], Time:54.88s, Train Loss: 1.9701, Train Accuracy: 24.19%, Validation Loss: 1.7481, Validation Accuracy: 33.62%
# Epoch [2/20], Time:54.97s, Train Loss: 1.5994, Train Accuracy: 39.67%, Validation Loss: 1.5872, Validation Accuracy: 44.90%
# Epoch [3/20], Time:54.80s, Train Loss: 1.3626, Train Accuracy: 50.50%, Validation Loss: 1.2477, Validation Accuracy: 53.64%
# Epoch [4/20], Time:54.73s, Train Loss: 1.1761, Train Accuracy: 57.94%, Validation Loss: 1.1136, Validation Accuracy: 60.54%
# Epoch [5/20], Time:54.96s, Train Loss: 1.0390, Train Accuracy: 63.49%, Validation Loss: 1.0311, Validation Accuracy: 64.44%
# Epoch [6/20], Time:54.68s, Train Loss: 0.9539, Train Accuracy: 66.64%, Validation Loss: 1.0122, Validation Accuracy: 65.64%
# Epoch [7/20], Time:55.08s, Train Loss: 0.8729, Train Accuracy: 70.14%, Validation Loss: 0.8630, Validation Accuracy: 69.40%
# ...

# %%
test_accuracy(model_vgg16_mod4)
# Out:
# Accuracy: 81.51%

# %%
model_resnet = models.resnet18(weights=None) 
model_resnet.fc = nn.Linear(model_resnet.fc.in_features, 10)  
model_resnet = model_resnet.to(device)
criterion = nn.CrossEntropyLoss()

optimizer_resnet = optim.SGD(model_resnet.parameters(), lr=0.01, momentum=0.9, weight_decay=5e-4)

# %%
train_plot(20,model_resnet,criterion,optimizer_resnet,trainloader,valloader)
# Out:
# Epoch [1/20], Time:28.43s, Train Loss: 1.5478, Train Accuracy: 45.67%, Validation Loss: 1.3011, Validation Accuracy: 54.50%
# Epoch [2/20], Time:19.34s, Train Loss: 1.1148, Train Accuracy: 60.81%, Validation Loss: 1.0676, Validation Accuracy: 62.32%
# Epoch [3/20], Time:19.80s, Train Loss: 0.9031, Train Accuracy: 68.46%, Validation Loss: 0.9990, Validation Accuracy: 65.32%
# Epoch [4/20], Time:19.57s, Train Loss: 0.7571, Train Accuracy: 73.50%, Validation Loss: 0.8713, Validation Accuracy: 69.50%
# Epoch [5/20], Time:19.75s, Train Loss: 0.6379, Train Accuracy: 77.78%, Validation Loss: 0.9044, Validation Accuracy: 69.40%
# Epoch [6/20], Time:19.21s, Train Loss: 0.5582, Train Accuracy: 80.24%, Validation Loss: 0.9004, Validation Accuracy: 69.62%
# Epoch [7/20], Time:19.28s, Train Loss: 0.4802, Train Accuracy: 83.36%, Validation Loss: 1.0552, Validation Accuracy: 68.00%
# ...

# %%
test_accuracy(model_resnet)
# Out:
# Accuracy: 73.71%

# %%
model_resnet2 = models.resnet18(weights=None)  
model_resnet2.conv1 = nn.Conv2d(in_channels=3, out_channels=64, kernel_size=3, stride=1, padding=1, bias=False)
model_resnet2.fc = nn.Linear(512, 10) 
model_resnet2 = model_resnet2.to(device)
optimizer_resnet2 = optim.SGD(model_resnet2.parameters(), lr=0.01, momentum=0.9, weight_decay=5e-4)

# %%
train_plot(20,model_resnet2,criterion,optimizer_resnet2,trainloader,valloader)
# Out:
# Epoch [1/20], Time:24.04s, Train Loss: 1.3481, Train Accuracy: 51.82%, Validation Loss: 1.0659, Validation Accuracy: 62.74%
# Epoch [2/20], Time:23.97s, Train Loss: 0.8751, Train Accuracy: 69.42%, Validation Loss: 0.8398, Validation Accuracy: 71.36%
# Epoch [3/20], Time:23.94s, Train Loss: 0.6443, Train Accuracy: 77.51%, Validation Loss: 0.8061, Validation Accuracy: 71.94%
# Epoch [4/20], Time:23.95s, Train Loss: 0.4990, Train Accuracy: 82.52%, Validation Loss: 0.7720, Validation Accuracy: 74.92%
# Epoch [5/20], Time:23.59s, Train Loss: 0.3806, Train Accuracy: 86.53%, Validation Loss: 0.8420, Validation Accuracy: 73.92%
# Epoch [6/20], Time:24.43s, Train Loss: 0.2933, Train Accuracy: 89.64%, Validation Loss: 0.7771, Validation Accuracy: 76.26%
# Epoch [7/20], Time:24.07s, Train Loss: 0.2242, Train Accuracy: 92.17%, Validation Loss: 0.9413, Validation Accuracy: 74.84%
# ...

# %%
test_accuracy(model_resnet2)
# Out:
# Accuracy: 77.44%

# %%
model_resnet3 = models.resnet18(weights=None)  
model_resnet3.conv1 = nn.Conv2d(in_channels=3, out_channels=64, kernel_size=3, stride=1, padding=1, bias=False)
model_resnet3.fc = nn.Linear(512, 10)  
model_resnet3 = model_resnet3.to(device)
optimizer_resnet2 = optim.SGD(model_resnet3.parameters(), lr=0.01, momentum=0.9, weight_decay=5e-4)

# %%
train_plot(20,model_resnet3,criterion,optimizer_resnet2,trainloader_transform,valloader_transform)
# Out:
# Epoch [1/20], Time:27.57s, Train Loss: 1.5348, Train Accuracy: 44.83%, Validation Loss: 1.3902, Validation Accuracy: 50.68%
# Epoch [2/20], Time:28.27s, Train Loss: 1.1182, Train Accuracy: 60.37%, Validation Loss: 1.1418, Validation Accuracy: 61.14%
# Epoch [3/20], Time:27.63s, Train Loss: 0.9359, Train Accuracy: 66.96%, Validation Loss: 0.8591, Validation Accuracy: 69.76%
# Epoch [4/20], Time:27.75s, Train Loss: 0.8126, Train Accuracy: 71.42%, Validation Loss: 0.8818, Validation Accuracy: 69.54%
# Epoch [5/20], Time:27.89s, Train Loss: 0.7134, Train Accuracy: 75.11%, Validation Loss: 0.8342, Validation Accuracy: 72.18%
# Epoch [6/20], Time:28.03s, Train Loss: 0.6579, Train Accuracy: 77.21%, Validation Loss: 0.6710, Validation Accuracy: 77.32%
# Epoch [7/20], Time:29.03s, Train Loss: 0.6110, Train Accuracy: 78.64%, Validation Loss: 0.6939, Validation Accuracy: 76.60%
# ...

# %%
test_accuracy(model_resnet3)
# Out:
# Accuracy: 85.13%

# %%
model_resnet4 = models.resnet18(weights=None)  
model_resnet4.conv1 = nn.Conv2d(in_channels=3, out_channels=64, kernel_size=3, stride=1, padding=1, bias=False)
model_resnet4.fc = nn.Linear(512, 10)  
model_resnet4 = model_resnet4.to(device)
optimizer_resnet4 = optim.SGD(model_resnet4.parameters(), lr=0.001, momentum=0.9, weight_decay=1e-3)

# %%
train_plot(20,model_resnet4,criterion,optimizer_resnet4,trainloader_transform,valloader_transform)
# Out:
# Epoch [1/20], Time:28.22s, Train Loss: 1.7217, Train Accuracy: 36.21%, Validation Loss: 1.4529, Validation Accuracy: 46.08%
# Epoch [2/20], Time:26.96s, Train Loss: 1.3584, Train Accuracy: 50.42%, Validation Loss: 1.2410, Validation Accuracy: 53.86%
# Epoch [3/20], Time:27.19s, Train Loss: 1.1988, Train Accuracy: 56.76%, Validation Loss: 1.1203, Validation Accuracy: 59.80%
# Epoch [4/20], Time:27.65s, Train Loss: 1.0823, Train Accuracy: 61.22%, Validation Loss: 1.0780, Validation Accuracy: 60.92%
# Epoch [5/20], Time:28.36s, Train Loss: 1.0019, Train Accuracy: 64.14%, Validation Loss: 1.0771, Validation Accuracy: 61.50%
# Epoch [6/20], Time:28.15s, Train Loss: 0.9333, Train Accuracy: 66.78%, Validation Loss: 0.9129, Validation Accuracy: 67.58%
# Epoch [7/20], Time:27.28s, Train Loss: 0.8779, Train Accuracy: 68.85%, Validation Loss: 0.8587, Validation Accuracy: 69.66%
# ...

# %%
test_accuracy(model_resnet4)
# Out:
# Accuracy: 83.94%

# %%
train_plot(10,model_resnet4,criterion,optimizer_resnet4,trainloader_transform,valloader_transform)
# Out:
# Epoch [1/10], Time:28.08s, Train Loss: 0.5059, Train Accuracy: 82.33%, Validation Loss: 0.5761, Validation Accuracy: 80.00%
# Epoch [2/10], Time:27.63s, Train Loss: 0.4894, Train Accuracy: 82.90%, Validation Loss: 0.5616, Validation Accuracy: 80.52%
# Epoch [3/10], Time:28.89s, Train Loss: 0.4717, Train Accuracy: 83.47%, Validation Loss: 0.5600, Validation Accuracy: 80.94%
# Epoch [4/10], Time:27.84s, Train Loss: 0.4664, Train Accuracy: 83.63%, Validation Loss: 0.6190, Validation Accuracy: 78.82%
# Epoch [5/10], Time:28.10s, Train Loss: 0.4548, Train Accuracy: 84.09%, Validation Loss: 0.5676, Validation Accuracy: 79.98%
# Epoch [6/10], Time:27.97s, Train Loss: 0.4401, Train Accuracy: 84.56%, Validation Loss: 0.5575, Validation Accuracy: 81.24%
# Epoch [7/10], Time:27.63s, Train Loss: 0.4290, Train Accuracy: 85.10%, Validation Loss: 0.5404, Validation Accuracy: 81.56%
# ...

# %%
test_accuracy(model_resnet4)
# Out:
# Accuracy: 82.90%

# %%
model_resnet5 = models.resnet18(weights=None)  
model_resnet5.conv1 = nn.Conv2d(in_channels=3, out_channels=64, kernel_size=3, stride=1, padding=1, bias=False)
model_resnet5.fc = nn.Linear(512, 10)  
model_resnet5= model_resnet5.to(device)
optimizer_resnet5 = optim.SGD(model_resnet5.parameters(), lr=0.01, momentum=0.9, weight_decay=5e-4)

# %%
train_plot(20,model_resnet5,criterion,optimizer_resnet5,trainloader2,valloader_transform)
# Out:
# Epoch [1/20], Time:24.70s, Train Loss: 1.5498, Train Accuracy: 43.37%, Validation Loss: 1.4021, Validation Accuracy: 48.96%
# Epoch [2/20], Time:23.58s, Train Loss: 1.1455, Train Accuracy: 58.93%, Validation Loss: 1.1083, Validation Accuracy: 60.20%
# Epoch [3/20], Time:23.81s, Train Loss: 0.9451, Train Accuracy: 66.32%, Validation Loss: 0.9194, Validation Accuracy: 67.54%
# Epoch [4/20], Time:24.29s, Train Loss: 0.8223, Train Accuracy: 71.06%, Validation Loss: 0.8927, Validation Accuracy: 68.26%
# Epoch [5/20], Time:24.50s, Train Loss: 0.7415, Train Accuracy: 74.00%, Validation Loss: 0.7182, Validation Accuracy: 74.66%
# Epoch [6/20], Time:24.10s, Train Loss: 0.6777, Train Accuracy: 76.21%, Validation Loss: 0.6697, Validation Accuracy: 75.68%
# Epoch [7/20], Time:23.61s, Train Loss: 0.6295, Train Accuracy: 78.05%, Validation Loss: 0.6633, Validation Accuracy: 76.58%
# ...

# %%
test_accuracy(model_resnet5)
# Out:
# Accuracy: 83.13%

# %%
model_mobilenet = models.mobilenet_v2(weights=None)
model_mobilenet.classifier[1] = nn.Linear(model_mobilenet.classifier[1].in_features, 10)
model_mobilenet = model_mobilenet.to(device)
criterion = nn.CrossEntropyLoss()
optimizer_mobilenet = optim.SGD(model_mobilenet.parameters(), lr=0.01, momentum=0.9, weight_decay=5e-4)

# %%
train_plot(20,model_mobilenet,criterion,optimizer_mobilenet,trainloader_transform,valloader_transform)
# Out:
# Epoch [1/20], Time:28.27s, Train Loss: 2.1098, Train Accuracy: 25.95%, Validation Loss: 1.7544, Validation Accuracy: 34.72%
# Epoch [2/20], Time:27.49s, Train Loss: 1.7190, Train Accuracy: 37.90%, Validation Loss: 1.6094, Validation Accuracy: 40.38%
# Epoch [3/20], Time:29.60s, Train Loss: 1.5686, Train Accuracy: 43.20%, Validation Loss: 1.4768, Validation Accuracy: 47.06%
# Epoch [4/20], Time:30.05s, Train Loss: 1.4612, Train Accuracy: 47.21%, Validation Loss: 1.4162, Validation Accuracy: 48.82%
# Epoch [5/20], Time:31.93s, Train Loss: 1.3850, Train Accuracy: 50.25%, Validation Loss: 1.3599, Validation Accuracy: 50.96%
# Epoch [6/20], Time:29.39s, Train Loss: 1.3238, Train Accuracy: 52.24%, Validation Loss: 1.3198, Validation Accuracy: 51.94%
# Epoch [7/20], Time:31.27s, Train Loss: 1.2685, Train Accuracy: 55.04%, Validation Loss: 1.2191, Validation Accuracy: 56.76%
# ...

# %%
test_accuracy(model_mobilenet)
# Out:
# Accuracy: 70.67%

# %%
model_mobilenet2 = models.mobilenet_v2(weights=None)  
model_mobilenet2.classifier[1] = nn.Linear(model_mobilenet.classifier[1].in_features, 10)  
model_mobilenet2 = model_mobilenet2.to(device)
criterion = nn.CrossEntropyLoss()
optimizer_mobilenet2 = optim.Adam(model_mobilenet2.parameters(), lr=0.001, weight_decay=5e-4)

# %%
train_plot(20,model_mobilenet2,criterion,optimizer_mobilenet2,trainloader_transform,valloader_transform)
# Out:
# Epoch [1/20], Time:29.38s, Train Loss: 2.0464, Train Accuracy: 24.44%, Validation Loss: 1.8094, Validation Accuracy: 31.12%
# Epoch [2/20], Time:28.46s, Train Loss: 1.7079, Train Accuracy: 36.47%, Validation Loss: 1.6355, Validation Accuracy: 40.82%
# Epoch [3/20], Time:29.27s, Train Loss: 1.5531, Train Accuracy: 43.02%, Validation Loss: 1.4961, Validation Accuracy: 45.06%
# Epoch [4/20], Time:27.89s, Train Loss: 1.4363, Train Accuracy: 48.14%, Validation Loss: 1.4053, Validation Accuracy: 49.50%
# Epoch [5/20], Time:27.47s, Train Loss: 1.3476, Train Accuracy: 51.91%, Validation Loss: 1.3263, Validation Accuracy: 52.94%
# Epoch [6/20], Time:27.32s, Train Loss: 1.2625, Train Accuracy: 55.41%, Validation Loss: 1.2080, Validation Accuracy: 58.08%
# Epoch [7/20], Time:27.36s, Train Loss: 1.1704, Train Accuracy: 58.69%, Validation Loss: 1.1400, Validation Accuracy: 60.24%
# ...

# %%
test_accuracy(model_mobilenet2)
# Out:
# Accuracy: 75.01%

# %%
model_mobilenet3 = models.mobilenet_v2(weights=None)  # MobileNetV2 
model_mobilenet3.classifier[1] = nn.Linear(model_mobilenet3.classifier[1].in_features, 10)  
model_mobilenet3 = model_mobilenet3.to(device)
criterion = nn.CrossEntropyLoss()
optimizer_mobilenet3 = optim.Adam(model_mobilenet3.parameters(), lr=0.005, weight_decay=5e-4)

# %%
train_plot(20,model_mobilenet3,criterion,optimizer_mobilenet3,trainloader_transform,valloader_transform)
# Out:
# Epoch [1/20], Time:30.47s, Train Loss: 2.1247, Train Accuracy: 21.23%, Validation Loss: 1.8863, Validation Accuracy: 26.02%
# Epoch [2/20], Time:29.84s, Train Loss: 1.7329, Train Accuracy: 32.55%, Validation Loss: 1.7020, Validation Accuracy: 33.66%
# Epoch [3/20], Time:29.51s, Train Loss: 1.5663, Train Accuracy: 40.55%, Validation Loss: 1.5587, Validation Accuracy: 41.52%
# Epoch [4/20], Time:29.35s, Train Loss: 1.4427, Train Accuracy: 46.82%, Validation Loss: 1.6789, Validation Accuracy: 39.02%
# Epoch [5/20], Time:27.98s, Train Loss: 1.3569, Train Accuracy: 51.08%, Validation Loss: 2.7919, Validation Accuracy: 25.48%
# Epoch [6/20], Time:28.69s, Train Loss: 1.3087, Train Accuracy: 53.34%, Validation Loss: 1.4710, Validation Accuracy: 47.88%
# Epoch [7/20], Time:27.09s, Train Loss: 1.2636, Train Accuracy: 55.02%, Validation Loss: 1.4361, Validation Accuracy: 50.52%
# ...

# %%
test_accuracy(model_mobilenet3)
# Out:
# Accuracy: 72.30%

# %%
model_mobilenet4 = models.mobilenet_v2(weights=None)  # MobileNetV2 
model_mobilenet4.classifier[1] = nn.Linear(model_mobilenet4.classifier[1].in_features, 10)  
model_mobilenet4 = model_mobilenet4.to(device)
criterion = nn.CrossEntropyLoss()

# %%
optimizer_mobilenet4 = optim.SGD(model_mobilenet4.parameters(), lr=0.01, momentum=0.9, weight_decay=5e-4)

# %%
train_plot(20,model_mobilenet4,criterion,optimizer_mobilenet4,trainloader,valloader)
# Out:
# Epoch [1/20], Time:28.80s, Train Loss: 1.9985, Train Accuracy: 29.86%, Validation Loss: 1.9163, Validation Accuracy: 37.96%
# Epoch [2/20], Time:23.76s, Train Loss: 1.6394, Train Accuracy: 42.49%, Validation Loss: 1.4391, Validation Accuracy: 48.74%
# Epoch [3/20], Time:23.27s, Train Loss: 1.4433, Train Accuracy: 48.75%, Validation Loss: 1.3627, Validation Accuracy: 51.10%
# Epoch [4/20], Time:23.61s, Train Loss: 1.3069, Train Accuracy: 53.38%, Validation Loss: 1.2839, Validation Accuracy: 55.30%
# Epoch [5/20], Time:22.66s, Train Loss: 1.2205, Train Accuracy: 56.68%, Validation Loss: 1.1722, Validation Accuracy: 58.68%
# Epoch [6/20], Time:23.82s, Train Loss: 1.1106, Train Accuracy: 60.55%, Validation Loss: 1.1471, Validation Accuracy: 58.76%
# Epoch [7/20], Time:23.11s, Train Loss: 1.0492, Train Accuracy: 63.09%, Validation Loss: 1.0554, Validation Accuracy: 62.90%
# ...

# %%
test_accuracy(model_mobilenet4)
# Out:
# Accuracy: 70.65%

# %%
model_mobilenet5 = models.mobilenet_v2(weights=None)  # MobileNetV2 
model_mobilenet5.classifier[1] = nn.Linear(model_mobilenet5.classifier[1].in_features, 10)  
model_mobilenet5 = model_mobilenet5.to(device)
criterion = nn.CrossEntropyLoss()
optimizer_mobilenet5 = optim.Adam(model_mobilenet5.parameters(), lr=0.001, weight_decay=5e-4)

# %%
train_plot(20,model_mobilenet5,criterion,optimizer_mobilenet5,trainloader,valloader)
# Out:
# Epoch [1/20], Time:25.80s, Train Loss: 1.9525, Train Accuracy: 27.64%, Validation Loss: 1.7126, Validation Accuracy: 38.24%
# Epoch [2/20], Time:25.32s, Train Loss: 1.5681, Train Accuracy: 42.91%, Validation Loss: 1.4998, Validation Accuracy: 46.20%
# Epoch [3/20], Time:25.15s, Train Loss: 1.3978, Train Accuracy: 49.61%, Validation Loss: 1.3596, Validation Accuracy: 52.24%
# Epoch [4/20], Time:25.23s, Train Loss: 1.2774, Train Accuracy: 54.86%, Validation Loss: 1.2776, Validation Accuracy: 54.90%
# Epoch [5/20], Time:25.29s, Train Loss: 1.1775, Train Accuracy: 58.42%, Validation Loss: 1.1480, Validation Accuracy: 60.12%
# Epoch [6/20], Time:25.31s, Train Loss: 1.0926, Train Accuracy: 61.83%, Validation Loss: 1.1571, Validation Accuracy: 60.22%
# Epoch [7/20], Time:25.16s, Train Loss: 1.0117, Train Accuracy: 65.01%, Validation Loss: 1.0071, Validation Accuracy: 65.28%
# ...

# %%
test_accuracy(model_mobilenet5)
# Out:
# Accuracy: 73.01%
